# %%
# https://thecleverprogrammer.com/2023/10/02/text-analysis-using-python/

import pandas as pd
import plotly.express as px
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from textblob import TextBlob
import spacy
from collections import defaultdict
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

nlp = spacy.load('en_core_web_sm')

data = pd.read_csv("articles.csv", encoding='latin-1')
print(data.head())
# Combine all titles into a single string
titles_text = ' '.join(data['Title'])

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(titles_text)

# Plot the Word Cloud
fig = px.imshow(wordcloud, title='Word Cloud of Titles')
fig.update_layout(showlegend=False)
fig.show()

# Sentiment Analysis
data['Sentiment'] = data['Article'].apply(lambda x: TextBlob(x).sentiment.polarity)

# Sentiment Distribution
fig = px.histogram(data, x='Sentiment', title='Sentiment Distribution')
fig.show()
# Out:
#                                              Article  \
# 0  Data analysis is the process of inspecting and...
# 1  The performance of a machine learning algorith...
# 2  You must have seen the news divided into categ...
# 3  When there are only two classes in a classific...
# 4  The Multinomial Naive Bayes is one of the vari...
#
#                                                Title
# 0                  Best Books to Learn Data Analysis
# 1         Assumptions of Machine Learning Algorithms
# 2          News Classification with Machine Learning
# 3  Multiclass Classification Algorithms in Machin...
# 4        Multinomial Naive Bayes in Machine Learning
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="52e7d2ab-474a-4ff0-b19f-d62503d8978e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52e7d2ab-474a-4ff0-b19f-d62503d8978e")) {                    Plotly.newPlot(                        "52e7d2ab-474a-4ff0-b19f-d62503d8978e",                        [{"name":"0","source":"...\u002f5hkMjsRNpBQaPf7yR93zj0zO5OV+c25556LkCQJduzYsWPHjh07dvoPDttws5gVjxKGkwAAgAAqRbEgVDAVEz8IiLQ7H8pRiGCeKG84Jl6HcAI67aQZ1\u002f9J6PeQlkqSVCGoE4L5ovwJqOh+BHXsdAMgzOmEdgthSiGJJgQRA+aB8idgouUI5kP7kHi1qXE8AMJzu4RgHoy9288HFc7lyr\u002fstJJGY30kKpjJdfyu02jHjh07duzYsWMz\u002fSawKDDRfYBISKKFNKVY1P\u002fDdVu5jpsQbnQXHxkAAKkkzNm4bgeuP8RzOdChsQizYhVhTEIwT4Q3BEF4gNcT5hzCnMEXLWcex6L+GNf8AIAg3GiUNxQINWnJwzU\u002fYILZwBBYhP4wIFwgCcJwBBOvZhyg04GUPI1wgtgdduzYsWPHjh07N0V\u002fCyzxeoTjDwAABK7dalG9a25dw3U9gqBO3fkAAFhU7+Pan3HdNo7sNQAgjBcIYxIqmMF1\u002fBYAbXcijaSlCFA5vReu3YxrfkAwT67jdwh3UIeZJM05CDeGdgMA3HAY5Q4C0kLoD3UjsFA5kDpc8y1H\u002fim7y44dO3b+Jp7743ByadVfTz\u002foKhWz+\u002fpCfx3Hjh07faVDwfQ\u002fKCZ+CJM8ShKNuGYju5MBJrwHAEi